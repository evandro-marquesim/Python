# %% [markdown]
# <a href="https://colab.research.google.com/github/evandro-marquesim/Python/blob/main/sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Como concatenar varios csvs em um unico csv

# %%
files = [file for file in os.listdir('/content/sales')]

all_months_data = pd.DataFrame()

for file in files :
  df = pd.read_csv('/content/sales/'+file)
  all_months_data = pd.concat([all_months_data, df])

all_months_data.to_csv('csv_completo.csv', index = False)

# %%
df = pd.read_csv('/content/csv_completo.csv')
df
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 0        194095          Wired Headphones                1      11.99
# 1        194096     AA Batteries (4-pack)                1       3.84
# 2        194097          27in FHD Monitor                1     149.99
# 3        194098          Wired Headphones                1      11.99
# 4        194099    AAA Batteries (4-pack)                2       2.99
# ...         ...                       ...              ...        ...
# 186845   176554  Lightning Charging Cable                1      14.95
# 186846   176555          27in FHD Monitor                1     149.99
# 186847   176556    AAA Batteries (4-pack)                3       2.99
# 186848   176557                    iPhone                1        700
# 186849   176557  Lightning Charging Cable                1      14.95
#
#             Order Date                           Purchase Address
# ...
